# %% [markdown]
# # Keras CNN Train Test Study
# ----
# Glenn Abastillas
#
# This notebook provides an example of training a CNN to identify images.

# %%
from keras.layers import Input, Dense, Dropout, Activation, Flatten, Convolution2D, MaxPooling2D, Conv2D, MaxPool2D
from keras.datasets import fashion_mnist, cifar10
from keras.utils import np_utils, to_categorical
from keras.models import Sequential
import numpy as np

import random

import matplotlib.pyplot as plt

# %% [markdown]
# #### Data Exploration

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train = x_train.astype('int')
x_test = x_test.astype('int')

x_train = x_train / 255
x_test = x_test / 255

# %%
y_train, y_test = to_categorical(y_train), to_categorical(y_test)

# %% [markdown]
# Plot all images.

# %%
fig, axes = plt.subplots(1, 8, figsize=(20, 5))

for i, ax in enumerate(axes.flatten()):
    current = random.randint(0, x_train.shape[0])
    ax.imshow(x_train[current], cmap='gray')
    ax.set_title(f'class {y_train[current].argmax()}', fontdict={'fontsize': 20})
    ax.set_yticks([])
# Out:
# Text(0.5, 0.98, 'Random Selection of Fashion Items')

# %%
x_train = x_train.reshape(x_train.shape[0], 1, *x_train.shape[1:])
x_test = x_test.reshape(x_test.shape[0], 1, *x_test.shape[1:])

# %% [markdown]
# #### Define Model

# %%
model = Sequential()

# Add layers
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=x_train.shape[1:]))
model.add(MaxPool2D())
model.add(Flatten())
model.add(Dense(100))
model.add(Dense(y_train[0].size, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #### Fit Model

# %%
model.fit(x_train, y_train, batch_size=1000, epochs=20, validation_data=(x_test, y_test), shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 30s 606us/step - loss: 2.1711 - accuracy: 0.2778 - val_loss: 1.6422 - val_accuracy: 0.4302
# Epoch 2/20
# 50000/50000 [==============================] - 29s 584us/step - loss: 1.5028 - accuracy: 0.4751 - val_loss: 1.4026 - val_accuracy: 0.5125
# Epoch 3/20
# 50000/50000 [==============================] - 29s 583us/step - loss: 1.3523 - accuracy: 0.5330 - val_loss: 1.3356 - val_accuracy: 0.5356
# Epoch 4/20
# 50000/50000 [==============================] - 30s 594us/step - loss: 1.2719 - accuracy: 0.5632 - val_loss: 1.2654 - val_accuracy: 0.5652
# Epoch 5/20
# 50000/50000 [==============================] - 28s 553us/step - loss: 1.2081 - accuracy: 0.5880 - val_loss: 1.2308 - val_accuracy: 0.5699
# Epoch 6/20
# 50000/50000 [==============================] - 31s 612us/step - loss: 1.1578 - accuracy: 0.6056 - val_loss: 1.1890 - val_accuracy: 0.5879
# Epoch 7/20
# 50000/50000 [==============================] - 31s 623us/step - loss: 1.1167 - accuracy: 0.6205 - val_loss: 1.1697 - val_accuracy: 0.5947
# Epoch 8/20
# 50000/50000 [==============================] - 29s 582us/step - loss: 1.0789 - accuracy: 0.6333 - val_loss: 1.1539 - val_accuracy: 0.5990
# Epoch 9/20
# 50000/50000 [==============================] - 31s 612us/step - loss: 1.0488 - accuracy: 0.6438 - val_loss: 1.1470 - val_accuracy: 0.6000
# Epoch 10/20
# 50000/50000 [==============================] - 31s 617us/step - loss: 1.0193 - accuracy: 0.6545 - val_loss: 1.1005 - val_accuracy: 0.6164
# Epoch 11/20
# 50000/50000 [==============================] - 30s 602us/step - loss: 1.0057 - accuracy: 0.6587 - val_loss: 1.0846 - val_accuracy: 0.6202
# Epoch 12/20
# 50000/50000 [==============================] - 31s 617us/step - loss: 0.9764 - accuracy: 0.6665 - val_loss: 1.0814 - val_accuracy: 0.6193
# Epoch 13/20
# 50000/50000 [==============================] - 31s 617us/step - loss: 0.9580 - accuracy: 0.6741 - val_loss: 1.0752 - val_accuracy: 0.6309
# Epoch 14/20
# 50000/50000 [==============================] - 31s 620us/step - loss: 0.9417 - accuracy: 0.6795 - val_loss: 1.0779 - val_accuracy: 0.6311
# Epoch 15/20
# 50000/50000 [==============================] - 31s 621us/step - loss: 0.9139 - accuracy: 0.6896 - val_loss: 1.0662 - val_accuracy: 0.6286
# Epoch 16/20
# 50000/50000 [==============================] - 31s 616us/step - loss: 0.8973 - accuracy: 0.6955 - val_loss: 1.0373 - val_accuracy: 0.6421
# Epoch 17/20
# 50000/50000 [==============================] - 31s 616us/step - loss: 0.8976 - accuracy: 0.6948 - val_loss: 1.0658 - val_accuracy: 0.6296
# Epoch 18/20
# 50000/50000 [==============================] - 31s 614us/step - loss: 0.8829 - accuracy: 0.6975 - val_loss: 1.0714 - val_accuracy: 0.6263
# Epoch 19/20
# 50000/50000 [==============================] - 31s 611us/step - loss: 0.8674 - accuracy: 0.7054 - val_loss: 1.0436 - val_accuracy: 0.6358
# Epoch 20/20
# 50000/50000 [==============================] - 31s 617us/step - loss: 0.8467 - accuracy: 0.7138 - val_loss: 1.0242 - val_accuracy: 0.6485

# %% [markdown]
# #### Predict on Some Examples

# %%
example_i = np.random.randint(0, x_test.shape[0])
example = x_test[example_i].reshape(1, 32, 32, 3)

y_actual = y_test[example_i]
y_pred = model.predict(example)

plt.imshow(example.reshape(32, 32, 3))
print(f'Actual label {y_actual.argmax()}\nPredicted label {y_pred.argmax()}')
# Out:
# Actual label 1
# Predicted label 1
